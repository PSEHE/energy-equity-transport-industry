# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import csv

pd.set_option('display.max_columns', None)
#pd.set_option('float_format', '{:.9f}'.format)

# %%
#Update when Audrey is able to provide start and endpoint markers for segment / block group pairs.

co_tract = pd.read_csv('Transportation/tractTraffic_June1/3_intersect/NV_rdTract_int.txt')
co_tract['roadlength'] = co_tract['end_point'] - co_tract['begin_poin']
segment_mi_sum = co_tract.groupby(['route_id','roadlength'], as_index=False)['segment_mi'].sum()
co_tract = co_tract.round(6)
co_tract['road_border?'] = np.where(co_tract['segment_mi'] > co_tract['roadlength'], 'True', 'False')

# %%
co_tract[co_tract['road_border?']=='True']
# Out:
#          FID  FID_ACS18_  OBJECTID  STATEFP  COUNTYFP  TRACTCE        GEOID  \
# 0          0         267       268       32         3     2976  32003002976
# 5          5          33        34       32        31   940200  32031940200
# 12        12          54        55       32        19   960800  32019960800
# 19        19         373       374       32         3     5315  32003005315
# 25        25         334       335       32         7   951500  32007951500
# ...      ...         ...       ...      ...       ...      ...          ...
# 52545  52545         580       581       32       510      800  32510000800
# 52552  52552         588       589       32         7   951401  32007951401
# 52570  52570          10        11       32         1   950100  32001950100
# 52581  52581         583       584       32       510      100  32510000100
# 52586  52586         429       430       32         5     2500  32005002500
#
# ...

# %%
r = 4769+48813

# %%
r
# Out:
# 53582

# %%
t = 4769/53582

# %%
t
# Out:
# 0.08900376992273525
